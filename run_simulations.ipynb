# %%
# %reload_ext autoreload
# %autoreload 2

from si_evolution import evo_fun

# %%
evo_fun(maxf = 500)
# Out:
# [     generation  trait_mean        lb        ub
#  0             1    0.587796  0.304843  0.870748
#  1             2    0.581981  0.298132  0.865831
#  2             3    0.573408  0.319117  0.827699
#  3             4    0.625691  0.390063  0.861319
#  4             5    0.669137  0.456934  0.881339
#  ..          ...         ...       ...       ...
#  495         496    0.812391  0.812391  0.812391
#  496         497    0.812391  0.812391  0.812391
#  497         498    0.812391  0.812391  0.812391
#  498         499    0.812391  0.812391  0.812391
#  499         500    0.812391  0.812391  0.812391
#
#  [500 rows x 4 columns],
#       generation  trait_mean        lb        ub
#  0             1    0.226202  0.094163  0.358241
#  1             2    0.206621  0.079020  0.334223
#  2             3    0.227137  0.096026  0.358248
#  3             4    0.218055  0.094762  0.341348
#  4             5    0.220331  0.115116  0.325546
#  ..          ...         ...       ...       ...
# ...
